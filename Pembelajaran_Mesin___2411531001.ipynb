# %% [markdown]
# <a href="https://colab.research.google.com/github/habibiputrar/DIF62128_2411531001_Habibi-Putra-Rizqullah/blob/main/Pembelajaran_Mesin___2411531001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
jumlah_buku = 0
jumlah_buku = jumlah_buku + 3
if jumlah_buku > 0:
    print('Saya Sudah Punya Buku')
    print(f'Total: {jumlah_buku} buku')
daftar_buku = 'Buku ' * jumlah_buku
print(daftar_buku)
# Out:
# Saya Sudah Punya Buku
# Total: 3 buku
# Buku Buku Buku

# %%
jumlah_buku = 3
type(jumlah_buku)
# Out:
# int

# %%
print(type(nama_siswa))
print(type(harga_buku))
print(type(sudah_baca))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
x = 15
y = 4

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x // y)
print(x % y)
print(x ** y)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %%
berat_gram = 2500
berat_kg = berat_gram / 1000
print(f'Berat: {berat_gram} gram = {berat_kg} kg')
# Out:
# Berat: 2500 gram = 2.5 kg

# %%
hasil1 = 5 + 4 * 3
hasil2 = (5 + 4) * 3

print(f'Tanpa kurung: {hasil1}')
print(f'Dengan kurung: {hasil2}')
# Out:
# Tanpa kurung: 17
# Dengan kurung: 27
